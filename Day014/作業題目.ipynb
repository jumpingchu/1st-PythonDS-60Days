# %% [markdown]
# 作業目標:<br>
# 1. 熟悉索引與欄位設定
# 2. 使用樞紐建立新資料

# %% [markdown]
# 作業重點:<br>
# 1. 多維度索引、欄位是有順序性的須注意
# 2. 使用樞紐建立資料需要注意參數<br>
#   index : 新資料的索引名稱<br>
#   columns : 新資料的欄位名稱<br>
#   values :新資料的值名稱

# %% [markdown]
# 題目: 運用下列分數資料重新建構資料，將索引(index)依序改為sex、class、student_id，欄位依序改成chinese_score、english_score、math_score<br><br>
# score_df = pd.DataFrame([[1,50,80,70,'boy',1],[2,60,45,50,'boy',2],[3,98,43,55,'boy',1],[4,70,69,89,'boy',2],[5,56,79,60,'girl',1],[6,60,68,55,'girl',2],[7,45,70,77,'girl',1],[8,55,77,76,'girl',2],[9,25,57,60,'girl',1],[10,88,40,43,'girl',3],[11,25,60,45,'boy',3],[12,80,60,23,'boy',3],[13,20,90,66,'girl',3],[14,50,50,50,'girl',3],[15,89,67,77,'girl',3]],columns=['student_id','math_score','english_score','chinese_score','sex','class'])

# %%
import pandas as pd
import numpy as np
score_df = pd.DataFrame([[1,50,80,70,'boy',1],[2,60,45,50,'boy',2],[3,98,43,55,'boy',1],[4,70,69,89,'boy',2],[5,56,79,60,'girl',1],[6,60,68,55,'girl',2],[7,45,70,77,'girl',1],[8,55,77,76,'girl',2],[9,25,57,60,'girl',1],[10,88,40,43,'girl',3],[11,25,60,45,'boy',3],[12,80,60,23,'boy',3],[13,20,90,66,'girl',3],[14,50,50,50,'girl',3],[15,89,67,77,'girl',3]],columns=['student_id','math_score','english_score','chinese_score','sex','class'])

# %%
score_df
# Out:
#     student_id  math_score  english_score  chinese_score   sex  class
# 0            1          50             80             70   boy      1
# 1            2          60             45             50   boy      2
# 2            3          98             43             55   boy      1
# 3            4          70             69             89   boy      2
# 4            5          56             79             60  girl      1
# 5            6          60             68             55  girl      2
# 6            7          45             70             77  girl      1
# 7            8          55             77             76  girl      2
# 8            9          25             57             60  girl      1
# 9           10          88             40             43  girl      3
# 10          11          25             60             45   boy      3
# 11          12          80             60             23   boy      3
# ...

# %% [markdown]
# ### 將索引(index)依序改為 sex、class、student_id，欄位依序改成 chinese_score、english_score、math_score

# %%
df_new = score_df.pivot(columns=['student_id', 'class', 'sex'], values=['chinese_score', 'english_score', 'math_score'])

# %%
df_new.stack().stack().stack()
# Out:
#                           chinese_score  english_score  math_score
#    sex  class student_id
# 0  boy  1     1                    70.0           80.0        50.0
# 1  boy  2     2                    50.0           45.0        60.0
# 2  boy  1     3                    55.0           43.0        98.0
# 3  boy  2     4                    89.0           69.0        70.0
# 4  girl 1     5                    60.0           79.0        56.0
# 5  girl 2     6                    55.0           68.0        60.0
# 6  girl 1     7                    77.0           70.0        45.0
# 7  girl 2     8                    76.0           77.0        55.0
# 8  girl 1     9                    60.0           57.0        25.0
# 9  girl 3     10                   43.0           40.0        88.0
# 10 boy  3     11                   45.0           60.0        25.0
# 11 boy  3     12                   23.0           60.0        80.0
# 12 girl 3     13                   66.0           90.0        20.0
# ...
